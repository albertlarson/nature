# %%
import numpy as np
import requests
import glob

# %%
smap_list = np.load('smap_h5.npy')

# %%
# smap_list[14:101] ### index of dates i'm interested in based on availability of radar data

# %%
x = glob.glob('smap_l3_36km/*.h5')
y = x[0][13:]
print(y)
# Out:
# SMAP_L3_SM_P_20150331_R18290_002.h5

# %%
smap_list[0][59:]
# Out:
# 'SMAP_L3_SM_P_20150331_R18290_002.h5'

# %%
lis = smap_list[14:101]

class SessionWithHeaderRedirection(requests.Session):
    AUTH_HOST = 'urs.earthdata.nasa.gov'

    def __init__(self, username, password):
        super().__init__()
        self.auth = (username, password)

    # Overrides from the library to keep headers when redirected to or from the NASA auth host.
    def rebuild_auth(self, prepared_request, response):
        headers = prepared_request.headers
        url = prepared_request.url
        if 'Authorization' in headers:
            original_parsed = requests.utils.urlparse(response.request.url)
            redirect_parsed = requests.utils.urlparse(url)
            if (original_parsed.hostname != redirect_parsed.hostname) and \
               redirect_parsed.hostname != self.AUTH_HOST and \
               original_parsed.hostname != self.AUTH_HOST:
                del headers['Authorization']
        return


# create session with the user credentials that will be used to authenticate access to the data

username=""
password=""
session = SessionWithHeaderRedirection(username, password)



# ***********************
# Loop through Files
# ***********************
destination_files = 'smap_l3_36km/*.h5'
y = [eeks[13:] for eeks in glob.glob(destination_files)]
not_dled = []
dled = []
for x in lis:
    if str(x[59:]) not in y:
        not_dled.append(x)
    if str(x[59:])  in y:
        dled.append(x)
print(f'dled: \t \n \t')
for x in dled:
    print('\t',x,'\t')
print(f'not dled: \t \n \t')
for x in not_dled:
    print('\t',x,'\t')


while True:
    for idx,i in enumerate(not_dled):
        try:

            # submit the request using the session
            response = session.get(i, stream=True)
            print(response.status_code)
            # raise an exception in case of http errors
            response.raise_for_status()
            # save the file
            with open(f'smap_l3_36km/{i[59:]}', 'wb') as fd:
                for data in response:
                    fd.write(data)
            fd.close()
        except requests.exceptions.HTTPError as e:
            # handle any errors here
            print('error',e)
    dled = []        
    not_dled = []
    for x in lis:
        y = [eeks[13:] for eeks in glob.glob(destination_files)]
        if str(x[59:]) not in y:
            not_dled.append(x)
        if str(x[59:]) in y:
            dled.append(x)
    print(f'dled: \t \n \t')
    for x in dled:
        print('\t',x,'\t')
    print(f'not dled: \t \n \t')
    for x in not_dled:
        print('\t',x,'\t')

            
    if len(not_dled) == 0:
        import sys
        sys.exit('no more left to download')
# Out:
# dled:
#
# 	 https://n5eil01u.ecs.nsidc.org/SMAP/SPL3SMP.008/2015.04.13/SMAP_L3_SM_P_20150413_R18290_001.h5
# 	 https://n5eil01u.ecs.nsidc.org/SMAP/SPL3SMP.008/2015.04.14/SMAP_L3_SM_P_20150414_R18290_001.h5
# 	 https://n5eil01u.ecs.nsidc.org/SMAP/SPL3SMP.008/2015.04.15/SMAP_L3_SM_P_20150415_R18290_001.h5
# 	 https://n5eil01u.ecs.nsidc.org/SMAP/SPL3SMP.008/2015.04.16/SMAP_L3_SM_P_20150416_R18290_001.h5
# 	 https://n5eil01u.ecs.nsidc.org/SMAP/SPL3SMP.008/2015.04.17/SMAP_L3_SM_P_20150417_R18290_001.h5
# 	 https://n5eil01u.ecs.nsidc.org/SMAP/SPL3SMP.008/2015.04.18/SMAP_L3_SM_P_20150418_R18290_001.h5
# 	 https://n5eil01u.ecs.nsidc.org/SMAP/SPL3SMP.008/2015.04.19/SMAP_L3_SM_P_20150419_R18290_001.h5
# 	 https://n5eil01u.ecs.nsidc.org/SMAP/SPL3SMP.008/2015.04.20/SMAP_L3_SM_P_20150420_R18290_001.h5
# 	 https://n5eil01u.ecs.nsidc.org/SMAP/SPL3SMP.008/2015.04.21/SMAP_L3_SM_P_20150421_R18290_001.h5
# 	 https://n5eil01u.ecs.nsidc.org/SMAP/SPL3SMP.008/2015.04.22/SMAP_L3_SM_P_20150422_R18290_001.h5
# ...

# %%
glob.glob(destination_files)[0][13:]
print(lis[0][59:])
# Out:
# SMAP_L3_SM_P_20150413_R18290_001.h5

# %%
destination_files = 'smap_l3_36km/*.h5'
not_dled = []
lis = smap_list[14:101]

for x in lis:
    y = [x[13:] for x in glob.glob(destination_files)]
    if str(x[13:]) not in y:
        not_dled.append(x)
print(not_dled)
# Out:
# ['https://n5eil01u.ecs.nsidc.org/SMAP/SPL3SMP.008/2015.04.13/SMAP_L3_SM_P_20150413_R18290_001.h5', 'https://n5eil01u.ecs.nsidc.org/SMAP/SPL3SMP.008/2015.04.14/SMAP_L3_SM_P_20150414_R18290_001.h5', 'https://n5eil01u.ecs.nsidc.org/SMAP/SPL3SMP.008/2015.04.15/SMAP_L3_SM_P_20150415_R18290_001.h5', 'https://n5eil01u.ecs.nsidc.org/SMAP/SPL3SMP.008/2015.04.16/SMAP_L3_SM_P_20150416_R18290_001.h5', 'https://n5eil01u.ecs.nsidc.org/SMAP/SPL3SMP.008/2015.04.17/SMAP_L3_SM_P_20150417_R18290_001.h5', 'https://n5eil01u.ecs.nsidc.org/SMAP/SPL3SMP.008/2015.04.18/SMAP_L3_SM_P_20150418_R18290_001.h5', 'https://n5eil01u.ecs.nsidc.org/SMAP/SPL3SMP.008/2015.04.19/SMAP_L3_SM_P_20150419_R18290_001.h5', 'https://n5eil01u.ecs.nsidc.org/SMAP/SPL3SMP.008/2015.04.20/SMAP_L3_SM_P_20150420_R18290_001.h5', 'https://n5eil01u.ecs.nsidc.org/SMAP/SPL3SMP.008/2015.04.21/SMAP_L3_SM_P_20150421_R18290_001.h5', 'https://n5eil01u.ecs.nsidc.org/SMAP/SPL3SMP.008/2015.04.22/SMAP_L3_SM_P_20150422_R18290_001.h5', 'https://n5eil01u
# ...
